# %%
import pandas as pd 
import time
import random
import os
from utils import get_data,data_processing
from datetime import datetime
import uuid

# %%
url = ['https://www.espn.com.co/futbol/posiciones/_/liga/esp.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/eng.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/ita.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/ger.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/fra.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/por.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/ned.1']
ligas = ['ESPAÑA','INGLATERRA','ITALIA','GERMANY','FRANCIA','PORTUGAL','HOLANDA']

df_ligas = {
    'LIGA':ligas,
    'URL':url
} 

df_ligas = pd.DataFrame(df_ligas)
df_ligas
# Out:
#          LIGA                                                URL
# 0      ESPAÑA  https://www.espn.com.co/futbol/posiciones/_/li...
# 1  INGLATERRA  https://www.espn.com.co/futbol/posiciones/_/li...
# 2      ITALIA  https://www.espn.com.co/futbol/posiciones/_/li...
# 3     GERMANY  https://www.espn.com.co/futbol/posiciones/_/li...
# 4     FRANCIA  https://www.espn.com.co/futbol/posiciones/_/li...
# 5    PORTUGAL  https://www.espn.com.co/futbol/posiciones/_/li...
# 6     HOLANDA  https://www.espn.com.co/futbol/posiciones/_/li...

# %%
df_ligas['URL'][1]
# Out:
# 'https://www.espn.com.co/futbol/posiciones/_/liga/eng.1'

# %%
df = pd.read_html(df_ligas['URL'][1])

# %%
len(df)
# Out:
# 2

# %%
df[0]
# Out:
#                        2024/2025
# 0                  1LIVLiverpool
# 1            2MCIManchester City
# 2                    3ARSArsenal
# 3                    4CHEChelsea
# 4                5AVLAston Villa
# 5     6BHABrighton & Hove Albion
# 6           7NEWNewcastle United
# 7                     8FULFulham
# 8          9TOTTottenham Hotspur
# 9         10FORNottingham Forest
# 10                11BRNBrentford
# 11          12WHUWest Ham United
# 12          13BOUAFC Bournemouth
# 13        14MUNManchester United
# 14           15LEILeicester City
# 15                  16EVEEverton
# 16             17IPSIpswich Town
# 17           18CRYCrystal Palace
# 18              19SOUSouthampton
# 19  20WOLWolverhampton Wanderers

# %%
df[1]
# Out:
#     J  G  E  P  GF  GC  DIF  PTS
# 0   7  6  0  1  13   2   11   18
# 1   7  5  2  0  17   8    9   17
# 2   7  5  2  0  15   6    9   17
# 3   7  4  2  1  16   8    8   14
# 4   7  4  2  1  12   9    3   14
# 5   7  3  3  1  13  10    3   12
# 6   7  3  3  1   8   7    1   12
# 7   7  3  2  2  10   8    2   11
# 8   7  3  1  3  14   8    6   10
# 9   7  2  4  1   7   6    1   10
# 10  7  3  1  3  13  13    0   10
# 11  7  2  2  3  10  11   -1    8
# 12  7  2  2  3   8  10   -2    8
# 13  7  2  2  3   5   8   -3    8
# 14  7  1  3  3   9  12   -3    6
# 15  7  1  2  4   7  15   -8    5
# 16  7  0  4  3   6  14   -8    4
# 17  7  0  3  4   5  10   -5    3
# 18  7  0  1  6   4  15  -11    1
# 19  7  0  1  6   9  21  -12    1

# %%
df=pd.concat([df[0],df[1]],ignore_index=True,axis=1)
df
# Out:
#                                0  1  2  3  4   5   6   7   8
# 0                  1LIVLiverpool  7  6  0  1  13   2  11  18
# 1            2MCIManchester City  7  5  2  0  17   8   9  17
# 2                    3ARSArsenal  7  5  2  0  15   6   9  17
# 3                    4CHEChelsea  7  4  2  1  16   8   8  14
# 4                5AVLAston Villa  7  4  2  1  12   9   3  14
# 5     6BHABrighton & Hove Albion  7  3  3  1  13  10   3  12
# 6           7NEWNewcastle United  7  3  3  1   8   7   1  12
# 7                     8FULFulham  7  3  2  2  10   8   2  11
# 8          9TOTTottenham Hotspur  7  3  1  3  14   8   6  10
# 9         10FORNottingham Forest  7  2  4  1   7   6   1  10
# 10                11BRNBrentford  7  3  1  3  13  13   0  10
# 11          12WHUWest Ham United  7  2  2  3  10  11  -1   8
# 12          13BOUAFC Bournemouth  7  2  2  3   8  10  -2   8
# 13        14MUNManchester United  7  2  2  3   5   8  -3   8
# 14           15LEILeicester City  7  1  3  3   9  12  -3   6
# 15                  16EVEEverton  7  1  2  4   7  15  -8   5
# 16             17IPSIpswich Town  7  0  4  3   6  14  -8   4
# 17           18CRYCrystal Palace  7  0  3  4   5  10  -5   3
# 18              19SOUSouthampton  7  0  1  6   4  15 -11   1
# 19  20WOLWolverhampton Wanderers  7  0  1  6   9  21 -12   1

# %%
df=df.rename(columns={0:'EQUIPO',1:'J', 2:'G', 3:'E', 4:'P', 5:'GF', 6:'GC', 7:'DIF', 8:'PTS'})
df['EQUIPO']=df['EQUIPO'].apply(lambda x: x[5:] if x[:2].isnumeric()==True else x[4:])
df['LIGA'] = df_ligas['LIGA'][1]

# %%
df
# Out:
#                      EQUIPO  J  G  E  P  GF  GC  DIF  PTS        LIGA
# 0                 Liverpool  7  6  0  1  13   2   11   18  INGLATERRA
# 1           Manchester City  7  5  2  0  17   8    9   17  INGLATERRA
# 2                   Arsenal  7  5  2  0  15   6    9   17  INGLATERRA
# 3                   Chelsea  7  4  2  1  16   8    8   14  INGLATERRA
# 4               Aston Villa  7  4  2  1  12   9    3   14  INGLATERRA
# 5    Brighton & Hove Albion  7  3  3  1  13  10    3   12  INGLATERRA
# 6          Newcastle United  7  3  3  1   8   7    1   12  INGLATERRA
# 7                    Fulham  7  3  2  2  10   8    2   11  INGLATERRA
# 8         Tottenham Hotspur  7  3  1  3  14   8    6   10  INGLATERRA
# 9         Nottingham Forest  7  2  4  1   7   6    1   10  INGLATERRA
# 10                Brentford  7  3  1  3  13  13    0   10  INGLATERRA
# 11          West Ham United  7  2  2  3  10  11   -1    8  INGLATERRA
# 12          AFC Bournemouth  7  2  2  3   8  10   -2    8  INGLATERRA
# 13        Manchester United  7  2  2  3   5   8   -3    8  INGLATERRA
# 14           Leicester City  7  1  3  3   9  12   -3    6  INGLATERRA
# 15                  Everton  7  1  2  4   7  15   -8    5  INGLATERRA
# 16             Ipswich Town  7  0  4  3   6  14   -8    4  INGLATERRA
# 17           Crystal Palace  7  0  3  4   5  10   -5    3  INGLATERRA
# 18              Southampton  7  0  1  6   4  15  -11    1  INGLATERRA
# 19  Wolverhampton Wanderers  7  0  1  6   9  21  -12    1  INGLATERRA

# %%
df_ligas.to_csv('df_ligas.csv',index=False)

# %%
def id_generator(team):

    return str(uuid.uuid1())[:8]

# %%
id_generator('carro')

# %%
id_generator('gato')

# %%
lista_resultado = 0

# %%
equipos = df_hola['EQUIPO'].unique()
lista_resultado = list(map(id_generator, equipos))

# %%
team_table = {

    'EQUIPO':equipos,
    'ID_TEAM':lista_resultado
}

df_team = pd.DataFrame(team_table)

# %%
df_team['ID_TEAM'].value_counts()

# %%
df_team.to_csv('team_table.csv',index=False)

# %%
pd.read_csv('df_ligas.csv')

# %%
df_final = pd.merge(df_hola,df_team,how='inner',on='EQUIPO')
df_final.columns
df_final = df_final[['ID_TEAM','EQUIPO', 'J', 'G', 'E', 'P', 'GF', 'GC', 'DIF', 'PTS', 'LIGA',
       'CREATED_AT']]
df_final

# %%
df_final.to_csv('premier_positions.csv',index=False)

# %%
lista_resultado[0]

# %%
hash('hola')

# %%
df_hola
